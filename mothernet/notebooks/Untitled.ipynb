# %%
import graphviz

# %%
with open("../first_epoch.dot", "r") as f:
    source = f.read()

# %%
graphviz.Source(source)

# %%
with open("../second_epoch.dot", "r") as f:
    source = f.read()
graphviz.Source(source)
