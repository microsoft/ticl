# %%
from mothernet.prediction.tabpfn import TabPFNClassifier
from models.basemodel import BaseModel
import os
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from mothernet.prediction.tabpfn import TabPFNClassifier
#       2 from models.basemodel import BaseModel
#       3 import os
#
# File /opt/hpcaas/.mounts/fs-07d502c998e146e70/yuchenzeng/tabflex/train_tabflex/mothernet/__init__.py:1
# ----> 1 from mothernet.prediction.tabpfn import TabPFNClassifier
#       3 __all__ = ["TabPFNClassifier"]
#
# File /opt/hpcaas/.mounts/fs-07d502c998e146e70/yuchenzeng/tabflex/train_tabflex/mothernet/prediction/__init__.py:1
# ----> 1 from .tabpfn import TabPFNClassifier
#       2 from .mothernet import MotherNetClassifier, EnsembleMeta
#       3 from .mothernet_additive import MotherNetAdditiveClassifier, MotherNetAdditiveRegressor
#
# File /opt/hpcaas/.mounts/fs-07d502c998e146e70/yuchenzeng/tabflex/train_tabflex/mothernet/prediction/tabpfn.py:9
#       6 from sklearn.decomposition import PCA
#       8 import numpy as np
# ----> 9 import torch
#      10 from sklearn.base import BaseEstimator, ClassifierMixin
#      11 from sklearn.preprocessing import LabelEncoder, PowerTransformer, QuantileTransformer, RobustScaler
#
# File /fsx-project/yuchenzeng/anaconda3/envs/linear_attention/lib/python3.10/site-packages/torch/__init__.py:367
#     365     if USE_GLOBAL_DEPS:
#     366         _load_global_deps()
# --> 367     from torch._C import *  # noqa: F403
#     370 class SymInt:
#     371     """
#     372     Like an int (including magic methods), but redirects all operations on the
#     373     wrapped node. This is used in particular to symbolically record operations
#     374     in the symbolic shape workflow.
#     375     """
#
# ImportError: /fsx-project/yuchenzeng/anaconda3/envs/linear_attention/lib/python3.10/site-packages/torch/lib/../../nvidia/cusparse/lib/libcusparse.so.12: undefined symbol: __nvJitLinkComplete_12_4, version libnvJitLink.so.12

# %%
model = TabPFNClassifier(
    device='cuda', 
    N_ensemble_configurations=32, 
    model_string = 'prior_diff_real_checkpoint_n_0',
    epoch = '100',
)
