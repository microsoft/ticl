# %%
import torch
torch.load('models_diff/tabpfn__emsize_512_nlayers_12_steps_2048_bs_32ada_lr_0.0001_1_gpu_07_24_2023_01_43_33_nooptimizer_epoch_1650.cpkt')
# Out:
# (OrderedDict([('transformer_encoder.layers.0.self_attn.in_proj_weight',
#                tensor([[ 0.0201, -0.0106,  0.0218,  ...,  0.0414,  0.0084, -0.0290],
#                        [ 0.0182,  0.0171,  0.0018,  ..., -0.0450,  0.0209, -0.0557],
#                        [ 0.0069, -0.0595,  0.0247,  ...,  0.0204, -0.0388,  0.0199],
#                        ...,
#                        [-0.0282, -0.0170,  0.0267,  ...,  0.0237, -0.0432, -0.0274],
#                        [-0.0182, -0.0265, -0.0297,  ..., -0.0179, -0.0446, -0.0032],
#                        [ 0.0121,  0.0520,  0.0040,  ..., -0.0057,  0.0539, -0.0365]],
#                       device='cuda:2')),
#               ('transformer_encoder.layers.0.self_attn.in_proj_bias',
#                tensor([ 0.0214,  0.0499,  0.0502,  ..., -0.0011, -0.0141,  0.0069],
#                       device='cuda:2')),
#               ('transformer_encoder.layers.0.self_attn.out_proj.weight',
# ...
